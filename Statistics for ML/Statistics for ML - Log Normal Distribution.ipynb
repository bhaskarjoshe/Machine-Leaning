# %%
import pandas as pd
import numpy as np
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('C:\\Data\\Custom\\income_log.csv')
df.head()
# Out:
#    income($)  count
# 0       5000   4371
# 1      10000   3295
# 2      15000   5825
# 3      20000   6047
# 4      25000   6097

# %%
sns.set(rc={'figure.figsize':(11,8)})
graph=sns.barplot(df['income($)'],df['count'])
graph.set_xticklabels(graph.get_xticklabels(),rotation=45,horizontalalignment='right');

# %%
sns.set(rc={'figure.figsize':(11,8)})
graph=sns.barplot(df['income($)'],df['count'])
graph.set_xticklabels(graph.get_xticklabels(),rotation=45,horizontalalignment='right');
graph.set(xscale='log');
